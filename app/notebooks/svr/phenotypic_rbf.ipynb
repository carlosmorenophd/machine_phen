# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from machines.predictions.svr_prediction import SVR_Prediction, SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum
from metrics.error_metric import ErrorMetric
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '/Users/yeiden/repo/machine_phen/data/phenotypic_obregon_151617.csv'
svr = SVR_Prediction(kernel=SvrKernelEnum.RBF)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(transform=TransformEnum.PASS)
preprocessing.build_train_and_test()

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
# print(x_train, y_train)
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metricts

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test)
metric.calculate_metric_prediction()
print('Mean squared error -> {}'.format(metric.mean_squared_error))
print('R2 -> {}'.format(metric.determination_coefficient))
print('MAPE -> {}'.format(metric.mean_absolute_percentage_error))
metric.print_list_on_error_upper(pivot=50, debug=False)
# Out:
# Mean squared error -> 9337.442058788336
# R2 -> 0.030578130122158598
# MAPE -> 0.13540025613620654
# [{'truth': 723.0, 'predict': 647.3928711025293, 'error': 75.60712889747072},
#  {'truth': 538.5554, 'predict': 648.013569216148, 'error': 109.45816921614801},
#  {'truth': 543.5405, 'predict': 642.2769077559401, 'error': 98.73640775594015},
#  {'truth': 576.6, 'predict': 643.0746032187648, 'error': 66.47460321876474},
#  {'truth': 710.0, 'predict': 647.4018178164075, 'error': 62.598182183592485},
#  {'truth': 460.0, 'predict': 632.1824702956577, 'error': 172.1824702956577},
#  {'truth': 723.0, 'predict': 655.4725799418767, 'error': 67.52742005812331},
#  {'truth': 716.0, 'predict': 647.3929722631547, 'error': 68.60702773684534},
#  {'truth': 799.0, 'predict': 647.3940772098458, 'error': 151.60592279015418},
#  {'truth': 700.0, 'predict': 647.3986584874364, 'error': 52.601341512563636},
#  {'truth': 459.2263, 'predict': 640.1794903184723, 'error': 180.9531903184723},
#  {'truth': 572.0, 'predict': 639.9159390512839, 'error': 67.91593905128389},
#  {'truth': 723.0, 'predict': 652.4730444188614, 'error': 70.52695558113862},
#  {'truth': 762.0, 'predict': 658.4856912473548, 'error': 103.5143087526452},
#  {'truth': 790.0426,
#   'predict': 662.3545854262628,
#   'error': 127.68801457373718},
#  {'truth': 535.2902, 'predict': 637.5307626885942, 'error': 102.2405626885942},
#  {'truth': 713.0, 'predict': 647.3984678391058, 'error': 65.60153216089418},
#  {'truth': 455.805, 'predict': 638.3719787272516, 'error': 182.56697872725164},
#  {'truth': 540.0, 'predict': 647.3885241134093, 'error': 107.38852411340929},
#  {'truth': 532.0, 'predict': 647.4009305400272, 'error': 115.40093054002716},
#  {'truth': 360.0, 'predict': 631.057664377142, 'error': 271.05766437714203},
#  {'truth': 719.887, 'predict': 657.6349682901546, 'error': 62.25203170984537},
#  {'truth': 709.6073, 'predict': 655.734101769548, 'error': 53.873198230451976},
#  {'truth': 481.9391,
#   'predict': 636.6529304479513,
#   'error': 154.71383044795135},
#  {'truth': 575.5569, 'predict': 641.7383986198037, 'error': 66.18149861980362},
#  {'truth': 453.0, 'predict': 643.0018824088509, 'error': 190.00188240885086},
#  {'truth': 729.0, 'predict': 647.3980745570387, 'error': 81.60192544296126},
#  {'truth': 724.0, 'predict': 647.401522042385, 'error': 76.59847795761505},
#  {'truth': 322.9881,
#   'predict': 631.2414781955167,
#   'error': 308.25337819551675},
#  {'truth': 712.0, 'predict': 647.3929750971575, 'error': 64.60702490284245},
#  {'truth': 709.0, 'predict': 647.3901486965087, 'error': 61.60985130349127},
#  {'truth': 587.3306, 'predict': 645.8596725210114, 'error': 58.52907252101136},
#  {'truth': 749.0, 'predict': 647.3920707004288, 'error': 101.6079292995712},
#  {'truth': 508.4414,
#   'predict': 636.9182253510221,
#   'error': 128.47682535102211},
#  {'truth': 568.2109, 'predict': 647.1549132604775, 'error': 78.9440132604775},
#  {'truth': 804.0, 'predict': 647.3947818287742, 'error': 156.60521817122583},
#  {'truth': 720.0, 'predict': 647.399158868947, 'error': 72.60084113105302},
#  {'truth': 590.605, 'predict': 641.3024382136806, 'error': 50.697438213680584},
#  {'truth': 438.9351,
#   'predict': 633.5652351891888,
#   'error': 194.63013518918882},
#  {'truth': 592.0, 'predict': 647.3898416559541, 'error': 55.389841655954115},
#  {'truth': 590.1555, 'predict': 644.6223531609794, 'error': 54.46685316097944},
#  {'truth': 519.2414,
#   'predict': 640.1781324084928,
#   'error': 120.93673240849284},
#  {'truth': 398.2896, 'predict': 626.8190647780201, 'error': 228.5294647780201},
#  {'truth': 774.0, 'predict': 666.2911151974164, 'error': 107.70888480258361},
#  {'truth': 427.0, 'predict': 647.3920534542995, 'error': 220.39205345429946},
#  {'truth': 715.0, 'predict': 653.6934532976284, 'error': 61.306546702371634},
#  {'truth': 724.0, 'predict': 647.3980696677843, 'error': 76.60193033221572},
#  {'truth': 500.4446,
#   'predict': 635.5237880822372,
#   'error': 135.07918808223718},
#  {'truth': 400.8056, 'predict': 631.1169806151688, 'error': 230.3113806151688},
#  {'truth': 409.865, 'predict': 634.9053982792175, 'error': 225.04039827921747},
#  {'truth': 587.0, 'predict': 647.3824825585134, 'error': 60.3824825585134},
#  {'truth': 592.0, 'predict': 644.3500252970882, 'error': 52.35002529708822},
#  {'truth': 468.0, 'predict': 632.0889555387308, 'error': 164.08895553873083},
#  {'truth': 557.3696, 'predict': 649.4812315448235, 'error': 92.11163154482347},
#  {'truth': 436.0, 'predict': 644.4431989657764, 'error': 208.44319896577645},
#  {'truth': 748.0, 'predict': 647.3955795235383, 'error': 100.60442047646166},
#  {'truth': 713.5909, 'predict': 655.8506367579153, 'error': 57.74026324208478},
#  {'truth': 724.2887, 'predict': 653.7791344710461, 'error': 70.50956552895389},
#  {'truth': 437.0, 'predict': 634.1728993819507, 'error': 197.17289938195074},
#  {'truth': 491.9464, 'predict': 635.6645491680289, 'error': 143.7181491680289},
#  {'truth': 591.1686, 'predict': 643.024348095176, 'error': 51.85574809517607},
#  {'truth': 226.1118, 'predict': 622.8055925868865, 'error': 396.6937925868865},
#  {'truth': 553.957, 'predict': 638.9096082272331, 'error': 84.9526082272331},
#  {'truth': 579.9627, 'predict': 646.3928056351638, 'error': 66.43010563516373},
#  {'truth': 304.5419, 'predict': 626.9349946841554, 'error': 322.3930946841554}]
