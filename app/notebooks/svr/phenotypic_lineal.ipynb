# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from machines.predictions.svr_prediction import SVR_Prediction, SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum
from metrics.error_metric import ErrorMetric
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '/Users/yeiden/repo/machine_phen/data/phenotypic_obregon_151617.csv'
svr = SVR_Prediction(kernel=SvrKernelEnum.LINEAR)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(transform=TransformEnum.PASS)
preprocessing.build_train_and_test()

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
# print(x_train, y_train)
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metricts

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test)
metric.calculate_metric_prediction()
print('Mean squared error -> {}'.format(metric.mean_squared_error))
print('R2 -> {}'.format(metric.determination_coefficient))
print('MAPE -> {}'.format(metric.mean_absolute_percentage_error))
metric.print_list_on_error_upper(pivot=50, debug=False)
# Out:
# Mean squared error -> 3204.0005285085776
# R2 -> 0.6673577020472106
# MAPE -> 0.07187069709357308
# [{'truth': 723.0, 'predict': 644.4698438012624, 'error': 78.53015619873759},
#  {'truth': 601.0, 'predict': 670.0726485044347, 'error': 69.07264850443471},
#  {'truth': 538.5554,
#   'predict': 593.2514083552292,
#   'error': 54.696008355229196},
#  {'truth': 543.5405, 'predict': 599.6835935769254, 'error': 56.14309357692548},
#  {'truth': 460.0, 'predict': 512.5383735759301, 'error': 52.53837357593011},
#  {'truth': 716.0, 'predict': 644.9209815176787, 'error': 71.07901848232132},
#  {'truth': 799.0, 'predict': 648.4847854035092, 'error': 150.51521459649075},
#  {'truth': 670.5991,
#   'predict': 611.4202921862366,
#   'error': 59.178807813763456},
#  {'truth': 459.2263, 'predict': 542.7437219805201, 'error': 83.51742198052017},
#  {'truth': 713.0, 'predict': 662.993953592761, 'error': 50.006046407238955},
#  {'truth': 624.0, 'predict': 695.4345126877656, 'error': 71.43451268776562},
#  {'truth': 625.0229, 'predict': 795.2751174747596, 'error': 170.2522174747595},
#  {'truth': 540.0, 'predict': 632.5436882354902, 'error': 92.54368823549021},
#  {'truth': 532.0, 'predict': 667.9962694348419, 'error': 135.9962694348419},
#  {'truth': 360.0, 'predict': 468.2377890289413, 'error': 108.23778902894128},
#  {'truth': 680.0, 'predict': 748.5472110613832, 'error': 68.54721106138322},
#  {'truth': 453.0, 'predict': 570.9665787067847, 'error': 117.96657870678473},
#  {'truth': 625.0, 'predict': 777.5991954262486, 'error': 152.59919542624857},
#  {'truth': 729.0, 'predict': 663.5616259699805, 'error': 65.43837403001953},
#  {'truth': 724.0, 'predict': 669.9176555973595, 'error': 54.0823444026405},
#  {'truth': 322.9881,
#   'predict': 444.19779697424974,
#   'error': 121.20969697424977},
#  {'truth': 616.961, 'predict': 717.3239628783545, 'error': 100.36296287835444},
#  {'truth': 712.0, 'predict': 646.0855600255659, 'error': 65.91443997443412},
#  {'truth': 709.0, 'predict': 637.4147003019812, 'error': 71.58529969801884},
#  {'truth': 749.0, 'predict': 644.0267784240773, 'error': 104.97322157592271},
#  {'truth': 568.2109, 'predict': 629.223881481134, 'error': 61.01298148113392},
#  {'truth': 804.0, 'predict': 651.9734827533016, 'error': 152.0265172466984},
#  {'truth': 720.0, 'predict': 664.4962355048979, 'error': 55.50376449510213},
#  {'truth': 645.0, 'predict': 728.9471747893026, 'error': 83.94717478930261},
#  {'truth': 774.0, 'predict': 862.1291217940511, 'error': 88.12912179405112},
#  {'truth': 427.0, 'predict': 636.7801204830525, 'error': 209.78012048305254},
#  {'truth': 724.0, 'predict': 661.3283343037242, 'error': 62.671665696275795},
#  {'truth': 707.0, 'predict': 778.5730285511004, 'error': 71.57302855110038},
#  {'truth': 400.8056,
#   'predict': 451.30352789970357,
#   'error': 50.49792789970354},
#  {'truth': 409.865, 'predict': 492.9248803166324, 'error': 83.05988031663242},
#  {'truth': 557.3696, 'predict': 651.6620530564455, 'error': 94.29245305644554},
#  {'truth': 436.0, 'predict': 619.4528611969786, 'error': 183.45286119697857},
#  {'truth': 748.0, 'predict': 653.2044470023015, 'error': 94.79555299769845},
#  {'truth': 638.4563, 'predict': 703.3279005709687, 'error': 64.87160057096867},
#  {'truth': 437.0, 'predict': 517.1012272677967, 'error': 80.10122726779673},
#  {'truth': 226.1118, 'predict': 318.8558056262905, 'error': 92.74400562629049},
#  {'truth': 641.0097, 'predict': 713.6986852091854, 'error': 72.68898520918549},
#  {'truth': 304.5419, 'predict': 396.1727569974378, 'error': 91.63085699743777}]
