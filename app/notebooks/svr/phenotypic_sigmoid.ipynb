# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from machines.predictions.svr_prediction import SVR_Prediction, SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum
from metrics.error_metric import ErrorMetric
from metrics.enums import MetricEnum
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '/Users/yeiden/repo/machine_phen/data/phenotypic_obregon_151617.csv'
svr = SVR_Prediction(kernel=SvrKernelEnum.SIGMOID)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(transform=TransformEnum.PASS)
preprocessing.build_train_and_test()

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
# print(x_train, y_train)
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metricts

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test)
metric.calculate_metric_prediction()
print('Root mean squared error -> {}'.format(metric.get_metric(metric=MetricEnum.ROOT_MEAN_SQUARED_ERROR)))
print('R2 -> {}'.format(metric.get_metric(metric=MetricEnum.R2_SCORE)))
print('MAPE -> {}'.format(metric.get_metric(metric=MetricEnum.MEAN_ABSOLUTE_PERCENTAGE_ERROR)))
metric.get_all_from_predict()
# Out:
# Root mean squared error -> 103.17631566372403
# R2 -> -0.10521030136847798
# MAPE -> 0.14428407753270772
# {'d2_absolute_error_score': -0.02665461030503624,
#  'd2_pinball_score': -0.02665461030503624,
#  'd2_tweedie_score': -0.10521030136847798,
#  'explained_variance_score': -0.009696506256622772,
#  'max_error': 424.14227453994124,
#  'mean_absolute_error': 71.63739831372959,
#  'mean_absolute_percentage_error': 0.14428407753270772,
#  'mean_gamma_deviance': 0.03343391539505171,
#  'mean_poisson_deviance': 18.59913614508072,
#  'mean_squared_error': 10645.352113940424,
#  'mean_squared_log_error': 0.039087025910262675,
#  'median_absolute_error': 46.21238024150745,
#  'r2_score': -0.10521030136847798,
#  'root_mean_squared_error': 103.17631566372403,
#  'root_mean_squared_log_error': 0.19770439021494357}
