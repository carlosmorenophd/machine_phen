# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from machines.predictions.svr_prediction import SVR_Prediction, SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum
from metrics.error_metric import ErrorMetric

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '/Users/yeiden/repo/machine_phen/data/phenotypic_obregon_151617.csv'
svr = SVR_Prediction(kernel=SvrKernelEnum.POLY)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(transform=TransformEnum.PASS)
preprocessing.build_train_and_test()

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
# print(x_train, y_train)
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metricts

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test)
metric.calculate_metric_prediction()
print('Mean squared error -> {}'.format(metric.mean_squared_error))
print('R2 -> {}'.format(metric.determination_coefficient))
print('MAPE -> {}'.format(metric.mean_absolute_percentage_error))
metric.print_list_on_error_upper(pivot=50, debug=False)
# Out:
# Mean squared error -> 7079.310483667684
# R2 -> 0.26501943858771515
# MAPE -> 0.1163318221750386
# [{'truth': 723.0, 'predict': 639.0125922855314, 'error': 83.98740771446865},
#  {'truth': 538.5554, 'predict': 641.3742891918744, 'error': 102.8188891918744},
#  {'truth': 543.5405, 'predict': 621.1624882939736, 'error': 77.62198829397369},
#  {'truth': 710.0, 'predict': 639.0633350199497, 'error': 70.9366649800503},
#  {'truth': 460.0, 'predict': 592.7757206724542, 'error': 132.7757206724542},
#  {'truth': 716.0, 'predict': 639.0131599152993, 'error': 76.9868400847007},
#  {'truth': 799.0, 'predict': 639.0193601141717, 'error': 159.98063988582828},
#  {'truth': 700.0, 'predict': 639.0452643345081, 'error': 60.95473566549185},
#  {'truth': 459.2263,
#   'predict': 614.5996547736795,
#   'error': 155.37335477367952},
#  {'truth': 723.0, 'predict': 660.2879721783922, 'error': 62.71202782160776},
#  {'truth': 762.0, 'predict': 692.4603105256233, 'error': 69.5396894743767},
#  {'truth': 790.0426, 'predict': 719.9413239491245, 'error': 70.10127605087553},
#  {'truth': 535.2902, 'predict': 606.8681543772731, 'error': 71.57795437727304},
#  {'truth': 713.0, 'predict': 639.044173579178, 'error': 73.95582642082195},
#  {'truth': 455.805, 'predict': 609.247839852112, 'error': 153.44283985211194},
#  {'truth': 625.0229,
#   'predict': 752.3012172578126,
#   'error': 127.27831725781255},
#  {'truth': 540.0, 'predict': 638.9883528156922, 'error': 98.98835281569222},
#  {'truth': 532.0, 'predict': 639.0582249356565, 'error': 107.05822493565654},
#  {'truth': 360.0, 'predict': 590.0169381628606, 'error': 230.01693816286058},
#  {'truth': 481.9391, 'predict': 604.428130931977, 'error': 122.48903093197697},
#  {'truth': 453.0, 'predict': 623.4905722619353, 'error': 170.4905722619353},
#  {'truth': 625.0, 'predict': 719.8746866510218, 'error': 94.87468665102176},
#  {'truth': 729.0, 'predict': 639.0419147679735, 'error': 89.95808523202652},
#  {'truth': 724.0, 'predict': 639.0616236787366, 'error': 84.93837632126338},
#  {'truth': 322.9881,
#   'predict': 590.4610531699269,
#   'error': 267.47295316992694},
#  {'truth': 616.961, 'predict': 674.2863843639178, 'error': 57.325384363917806},
#  {'truth': 712.0, 'predict': 639.0131650728949, 'error': 72.98683492710506},
#  {'truth': 709.0, 'predict': 638.9973840380658, 'error': 70.00261596193423},
#  {'truth': 749.0, 'predict': 639.0081024309628, 'error': 109.99189756903718},
#  {'truth': 508.4414, 'predict': 605.17099714498, 'error': 96.72959714498},
#  {'truth': 568.2109, 'predict': 638.1179250901346, 'error': 69.90702509013454},
#  {'truth': 804.0, 'predict': 639.0233118769523, 'error': 164.97668812304767},
#  {'truth': 720.0, 'predict': 639.0481007015123, 'error': 80.95189929848766},
#  {'truth': 438.9351,
#   'predict': 596.2433170151135,
#   'error': 157.30821701511348},
#  {'truth': 519.2414, 'predict': 614.608657710459, 'error': 95.36725771045906},
#  {'truth': 398.2896,
#   'predict': 580.1870032512762,
#   'error': 181.89740325127622},
#  {'truth': 427.0, 'predict': 639.0080588947718, 'error': 212.0080588947718},
#  {'truth': 724.0, 'predict': 639.0419101562835, 'error': 84.9580898437165},
#  {'truth': 500.4446,
#   'predict': 601.3647236813664,
#   'error': 100.92012368136642},
#  {'truth': 400.8056,
#   'predict': 590.1625822310099,
#   'error': 189.35698223100985},
#  {'truth': 409.865, 'predict': 599.7197466556806, 'error': 189.85474665568063},
#  {'truth': 629.6769, 'predict': 680.5116359254552, 'error': 50.83473592545511},
#  {'truth': 587.0, 'predict': 638.9551395056249, 'error': 51.95513950562486},
#  {'truth': 468.0, 'predict': 592.5309354501688, 'error': 124.53093545016884},
#  {'truth': 557.3696, 'predict': 647.2562269583052, 'error': 89.88662695830521},
#  {'truth': 436.0, 'predict': 628.3590349835581, 'error': 192.3590349835581},
#  {'truth': 748.0, 'predict': 639.0278248112179, 'error': 108.9721751887821},
#  {'truth': 724.2887, 'predict': 666.4833257223387, 'error': 57.80537427766126},
#  {'truth': 437.0, 'predict': 597.8095384233136, 'error': 160.8095384233136},
#  {'truth': 491.9464,
#   'predict': 601.7385398461031,
#   'error': 109.79213984610311},
#  {'truth': 226.1118,
#   'predict': 571.4028599438863,
#   'error': 345.29105994388624},
#  {'truth': 553.957, 'predict': 610.8342864998305, 'error': 56.87728649983046},
#  {'truth': 579.9627, 'predict': 635.2683328145193, 'error': 55.3056328145193},
#  {'truth': 304.5419, 'predict': 580.452465291843, 'error': 275.91056529184306}]
