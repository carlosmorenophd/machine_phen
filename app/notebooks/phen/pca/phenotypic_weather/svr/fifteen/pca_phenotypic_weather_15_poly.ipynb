# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../../../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from machines.predictions.svr_prediction import SVR_Prediction
from machines.enums import SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum, StandardScaleEnum
from metrics.error_metric import ErrorMetric
from metrics.enums import MetricEnum, PlotLegends

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '../../../../../../../data/phen/original/phenotypic_weather_obregon_151617_fifteen.csv'
print(os.getcwd())
svr = SVR_Prediction(kernel=SvrKernelEnum.POLY)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(
    transform=TransformEnum.PCA,
    standard_scale=StandardScaleEnum.BASIC,
)
preprocessing.build_train_and_test()
# Out:
# /phen/app/notebooks/phen/pca/phenotypic_weather/svr/fifteen

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metrics

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test, x_test=x_test)
metric.calculate_metric_prediction()
print('Root mean squared error -> {}'.format(metric.get_metric(metric=MetricEnum.ROOT_MEAN_SQUARED_ERROR)))
print('R2 -> {}'.format(metric.get_metric(metric=MetricEnum.R2_SCORE)))
print('MAPE -> {}'.format(metric.get_metric(metric=MetricEnum.MEAN_ABSOLUTE_PERCENTAGE_ERROR)))
metric.get_all_from_predict()
# Out:
# Root mean squared error -> 102.74077840784571
# R2 -> -0.09589916677603583
# MAPE -> 0.14367525704319267
# {'d2_absolute_error_score': -0.021739573816560442,
#  'd2_pinball_score': -0.021739573816560442,
#  'd2_tweedie_score': -0.09589916677603605,
#  'explained_variance_score': 0.00031987542704292604,
#  'max_error': 424.1927260577763,
#  'mean_absolute_error': 71.29443932526624,
#  'mean_absolute_percentage_error': 0.14367525704319267,
#  'mean_gamma_deviance': 0.03322194110482918,
#  'mean_poisson_deviance': 18.46125650773284,
#  'mean_squared_error': 10555.667547850057,
#  'mean_squared_log_error': 0.03884709892855712,
#  'median_absolute_error': 45.929213773774734,
#  'r2_score': -0.09589916677603583,
#  'root_mean_squared_error': 102.74077840784571,
#  'root_mean_squared_log_error': 0.19709667406772016}

# %% [markdown]
# Plots:

# %%
legend = PlotLegends()
legend.first_plot_label = "Yield predict"
legend.second_plot_label = "Regression"
legend.title = "Plot of Yield and regression"
legend.x_label = "Yield test"
legend.y_label = "Yield predict"
metric.plot_true_vs_predicted(legend=legend)

# %% [markdown]
# Plot $r^2$

# %%
legend = PlotLegends()
legend.first_plot_label = "{variable}, and yield test"
legend.second_plot_label = "{variable}, and yield predict"
legend.title = "Plot of {variable} ans yield with R2 = {r2:.2f}"
legend.x_label = "{variable}"
legend.y_label = "Yield predict"
features = preprocessing.get_name_features()
#metric.plot_r2_predicted(legend=legend, features=features)

# %% [markdown]
# Get the predict that are more bigger that .05

# %%
metric.list_percentage_error_upper(pivot=.04, sort = 'error')
# Out:
# [{'truth': 226.1118,
#   'predict': 650.3045260577763,
#   'error': 1.8760309106281776},
#  {'truth': 304.5419,
#   'predict': 650.3105311798482,
#   'error': 1.1353729361373532},
#  {'truth': 322.9881,
#   'predict': 650.3399795259755,
#   'error': 1.0135106510920235},
#  {'truth': 360.0, 'predict': 650.324374179654, 'error': 0.8064565949434833},
#  {'truth': 398.2896, 'predict': 650.3520065989219, 'error': 0.632862134986507},
#  {'truth': 400.8056, 'predict': 650.32424302741, 'error': 0.6225428063565229},
#  {'truth': 409.865, 'predict': 650.3457129609133, 'error': 0.5867315163795719},
#  {'truth': 427.0, 'predict': 650.3556067926402, 'error': 0.5230810463527873},
#  {'truth': 436.0, 'predict': 650.3499890087326, 'error': 0.4916284151576435},
#  {'truth': 437.0, 'predict': 650.3456451768944, 'error': 0.4882051377045639},
#  {'truth': 438.9351,
#   'predict': 650.3624895545017,
#   'error': 0.48168257574867396},
#  {'truth': 453.0, 'predict': 650.3458379442579, 'error': 0.4356420263670153},
#  {'truth': 455.805,
#   'predict': 650.3744875629544,
#   'error': 0.42687001582464956},
#  {'truth': 459.2263,
#   'predict': 650.3478468397028,
#   'error': 0.41618162295953615},
#  {'truth': 460.0, 'predict': 650.3450027986953, 'error': 0.4137934843449898},
#  {'truth': 468.0, 'predict': 650.3414304684669, 'error': 0.38961844117193783},
#  {'truth': 481.9391,
#   'predict': 650.3335729563495,
#   'error': 0.34941027394612617},
#  {'truth': 491.9464,
#   'predict': 650.3482279340175,
#   'error': 0.32199001341206585},
#  {'truth': 500.4446,
#   'predict': 650.3315285697896,
#   'error': 0.29950753503942223},
#  {'truth': 508.4414,
#   'predict': 650.3351806357953,
#   'error': 0.27907597736100026},
#  {'truth': 519.2414,
#   'predict': 650.3255328005002,
#   'error': 0.25245316109328003},
#  {'truth': 532.0, 'predict': 650.375738623776, 'error': 0.22251078688679696},
#  {'truth': 535.2902,
#   'predict': 650.3321780459688,
#   'error': 0.21491515825615484},
#  {'truth': 538.5554,
#   'predict': 650.3563022927722,
#   'error': 0.20759406050477297},
#  {'truth': 540.0, 'predict': 650.3720591885598, 'error': 0.2043927022010366},
#  {'truth': 543.5405,
#   'predict': 650.3672026399009,
#   'error': 0.19653862525405374},
#  {'truth': 804.0, 'predict': 650.4361590388604, 'error': 0.19099980219047213},
#  {'truth': 799.0, 'predict': 650.3867815904138, 'error': 0.18599902178921932},
#  {'truth': 790.0426,
#   'predict': 650.3775294334669,
#   'error': 0.1767816957801176},
#  {'truth': 553.957, 'predict': 650.3528545343586, 'error': 0.1740132438697563},
#  {'truth': 557.3696,
#   'predict': 650.3758732929392,
#   'error': 0.16686642632274748},
#  {'truth': 774.0, 'predict': 650.4354907833844, 'error': 0.15964406875531736},
#  {'truth': 762.0, 'predict': 650.4358982321137, 'error': 0.14640958237255422},
#  {'truth': 568.2109,
#   'predict': 650.3687803321575,
#   'error': 0.14459046866604888},
#  {'truth': 572.0, 'predict': 650.3622756377654, 'error': 0.1369969853807087},
#  {'truth': 749.0, 'predict': 650.4073564844658, 'error': 0.1316323678445049},
#  {'truth': 748.0, 'predict': 650.4288048454783, 'error': 0.13044277427075088},
#  {'truth': 575.5569,
#   'predict': 650.3357987769123,
#   'error': 0.12992442411325836},
#  {'truth': 576.6, 'predict': 650.3414636709031, 'error': 0.12789015551665459},
#  {'truth': 579.9627,
#   'predict': 650.3736440178989,
#   'error': 0.12140598700209311},
#  {'truth': 587.0, 'predict': 650.4225017586493, 'error': 0.10804514780008403},
#  {'truth': 729.0, 'predict': 650.4026562715426, 'error': 0.10781528632161512},
#  {'truth': 587.3306,
#   'predict': 650.355549541304,
#   'error': 0.10730745093360358},
#  {'truth': 724.2887,
#   'predict': 650.3761897488413,
#   'error': 0.1020484100485879},
#  {'truth': 590.1555,
#   'predict': 650.3598527254048,
#   'error': 0.1020143889625783},
#  {'truth': 724.0, 'predict': 650.3804311280094, 'error': 0.10168448739225225},
#  {'truth': 724.0, 'predict': 650.4140153421854, 'error': 0.10163810035609752},
#  {'truth': 590.605,
#   'predict': 650.4240433209429,
#   'error': 0.10128434964306586},
#  {'truth': 723.0, 'predict': 650.3681960552364, 'error': 0.10045892661793035},
#  {'truth': 723.0, 'predict': 650.4173056114936, 'error': 0.10039100192047913},
#  {'truth': 723.0, 'predict': 650.4199076414532, 'error': 0.10038740298554195},
#  {'truth': 591.1686,
#   'predict': 650.3671397098664,
#   'error': 0.10013816652282682},
#  {'truth': 592.0, 'predict': 650.3960769862247, 'error': 0.09864202193619032},
#  {'truth': 592.0, 'predict': 650.3893900637786, 'error': 0.09863072645908547},
#  {'truth': 720.0, 'predict': 650.3885491430465, 'error': 0.09668257063465767},
#  {'truth': 719.887,
#   'predict': 650.4031739688255,
#   'error': 0.09652046228251716},
#  {'truth': 716.0, 'predict': 650.3577527687991, 'error': 0.09167911624469405},
#  {'truth': 715.0, 'predict': 650.3626094395568, 'error': 0.09040194483978076},
#  {'truth': 713.5909,
#   'predict': 650.3774483912274,
#   'error': 0.08858500242754305},
#  {'truth': 713.0, 'predict': 650.40095336028, 'error': 0.08779669935444596},
#  {'truth': 598.2015,
#   'predict': 650.3442096101983,
#   'error': 0.08716579548897531},
#  {'truth': 712.0, 'predict': 650.3635097147563, 'error': 0.0865681043332074},
#  {'truth': 710.0, 'predict': 650.3882416086988, 'error': 0.08396022308633977},
#  {'truth': 600.1704,
#   'predict': 650.347966841618,
#   'error': 0.08360553409767967},
#  {'truth': 709.6073,
#   'predict': 650.3193330039404,
#   'error': 0.08355039047098246},
#  {'truth': 709.0, 'predict': 650.3798213310415, 'error': 0.08268008274888362},
#  {'truth': 601.0, 'predict': 650.363079548622, 'error': 0.0821349077348119},
#  {'truth': 707.0, 'predict': 650.4270790849358, 'error': 0.08001827569316007},
#  {'truth': 602.5863,
#   'predict': 650.3359052750835,
#   'error': 0.07924110666817925},
#  {'truth': 603.0, 'predict': 650.3822298066094, 'error': 0.07857749553334895},
#  {'truth': 704.7524,
#   'predict': 650.3547379161607,
#   'error': 0.07718691285597501},
#  {'truth': 604.1609,
#   'predict': 650.3464051619736,
#   'error': 0.0764457037222595},
#  {'truth': 604.6565,
#   'predict': 650.3294223855759,
#   'error': 0.07553532027783677},
#  {'truth': 703.2617,
#   'predict': 650.3679263081664,
#   'error': 0.07521207779669167},
#  {'truth': 605.295,
#   'predict': 650.3707218455007,
#   'error': 0.07446901402704593},
#  {'truth': 607.1254,
#   'predict': 650.3847778200262,
#   'error': 0.07125278866610786},
#  {'truth': 607.2419,
#   'predict': 650.3911562306452,
#   'error': 0.07105777159093463},
#  {'truth': 700.0, 'predict': 650.35886627835, 'error': 0.0709159053166429},
#  {'truth': 695.4481,
#   'predict': 650.3456487818983,
#   'error': 0.06485379889326277},
#  {'truth': 611.0, 'predict': 650.3052835157855, 'error': 0.06432943292272586},
#  {'truth': 694.1178,
#   'predict': 650.3768406367006,
#   'error': 0.06301662248583646},
#  {'truth': 612.0, 'predict': 650.4332319090655, 'error': 0.0627993985442247},
#  {'truth': 612.1224,
#   'predict': 650.4140920308037,
#   'error': 0.06255561311071722},
#  {'truth': 691.1499,
#   'predict': 650.3820517786415,
#   'error': 0.058985537321727836},
#  {'truth': 690.806,
#   'predict': 650.3728398330868,
#   'error': 0.05853041254261433},
#  {'truth': 615.0, 'predict': 650.4021039971058, 'error': 0.057564396743261415},
#  {'truth': 615.0, 'predict': 650.3805143560195, 'error': 0.057529291635804045},
#  {'truth': 616.0, 'predict': 650.3860126550414, 'error': 0.055821449115327014},
#  {'truth': 616.1065,
#   'predict': 650.4076552802809,
#   'error': 0.05567406816886514},
#  {'truth': 688.527, 'predict': 650.395425199987, 'error': 0.05538137908900163},
#  {'truth': 617.0, 'predict': 650.4104194510087, 'error': 0.0541497884133042},
#  {'truth': 616.961,
#   'predict': 650.3535348091885,
#   'error': 0.05412422310192789},
#  {'truth': 687.2559,
#   'predict': 650.3599522038224,
#   'error': 0.0536858945789735},
#  {'truth': 686.0, 'predict': 650.4007725095123, 'error': 0.051893917624617626},
#  {'truth': 618.5932,
#   'predict': 650.3552315256251,
#   'error': 0.05134558790110374},
#  {'truth': 685.0, 'predict': 650.3794127863387, 'error': 0.05054100323162239},
#  {'truth': 619.8774,
#   'predict': 650.3633774251897,
#   'error': 0.04918065640913789},
#  {'truth': 622.0, 'predict': 650.3373925376496, 'error': 0.045558508902973686},
#  {'truth': 681.0, 'predict': 650.3943079949207, 'error': 0.044942279008926986},
#  {'truth': 623.0015,
#   'predict': 650.3986072343212,
#   'error': 0.04397598919797336},
#  {'truth': 680.2429,
#   'predict': 650.3802219062011,
#   'error': 0.04390002173311751},
#  {'truth': 680.0, 'predict': 650.3979463320339, 'error': 0.043532431864655975},
#  {'truth': 679.5885,
#   'predict': 650.3729876647525,
#   'error': 0.0429900040027862},
#  {'truth': 623.6013,
#   'predict': 650.3500503456518,
#   'error': 0.04289399387982631},
#  {'truth': 679.2389,
#   'predict': 650.417125352047,
#   'error': 0.042432455867814564},
#  {'truth': 624.0, 'predict': 650.3891061635715, 'error': 0.04229023423649272},
#  {'truth': 624.0551,
#   'predict': 650.3137857972923,
#   'error': 0.042077511741018196},
#  {'truth': 624.4419,
#   'predict': 650.3698079091187,
#   'error': 0.04152172989851999},
#  {'truth': 677.9521,
#   'predict': 650.3891498885826,
#   'error': 0.040656191066326695},
#  {'truth': 625.0, 'predict': 650.3838716636452, 'error': 0.04061419466183233},
#  {'truth': 625.0229,
#   'predict': 650.3884719738237,
#   'error': 0.04058342818130927}]
