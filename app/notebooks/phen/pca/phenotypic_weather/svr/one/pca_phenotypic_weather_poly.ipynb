# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../../../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from machines.predictions.svr_prediction import SVR_Prediction
from machines.enums import SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum, StandardScaleEnum
from metrics.error_metric import ErrorMetric
from metrics.enums import MetricEnum, PlotLegends

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '../../../../../../../data/phen/original/phenotypic_weather_obregon_original_151617.csv'
print(os.getcwd())
svr = SVR_Prediction(kernel=SvrKernelEnum.POLY)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(
    transform=TransformEnum.PCA,
    standard_scale=StandardScaleEnum.BASIC,
)
preprocessing.build_train_and_test()
# Out:
# /phen/app/notebooks/phen/pca/phenotypic_weather/svr/daily

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metrics

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test, x_test=x_test)
metric.calculate_metric_prediction()
print('Root mean squared error -> {}'.format(metric.get_metric(metric=MetricEnum.ROOT_MEAN_SQUARED_ERROR)))
print('R2 -> {}'.format(metric.get_metric(metric=MetricEnum.R2_SCORE)))
print('MAPE -> {}'.format(metric.get_metric(metric=MetricEnum.MEAN_ABSOLUTE_PERCENTAGE_ERROR)))
metric.get_all_from_predict()
# Out:
# Root mean squared error -> 102.62156994105425
# R2 -> -0.0933575339123458
# MAPE -> 0.1434613551146958
# {'d2_absolute_error_score': -0.020645475701069227,
#  'd2_pinball_score': -0.020645475701069227,
#  'd2_tweedie_score': -0.0933575339123458,
#  'explained_variance_score': -6.77732092668748e-10,
#  'max_error': 423.8043723662216,
#  'mean_absolute_error': 71.21809588735925,
#  'mean_absolute_percentage_error': 0.1434613551146958,
#  'mean_gamma_deviance': 0.03316401905618244,
#  'mean_poisson_deviance': 18.423600357973793,
#  'mean_squared_error': 10531.18661716669,
#  'mean_squared_log_error': 0.03876776481237037,
#  'median_absolute_error': 45.64359988737459,
#  'r2_score': -0.0933575339123458,
#  'root_mean_squared_error': 102.62156994105425,
#  'root_mean_squared_log_error': 0.19689531434843838}

# %% [markdown]
# Plots:

# %%
legend = PlotLegends()
legend.first_plot_label = "Yield predict"
legend.second_plot_label = "Regression"
legend.title = "Plot of Yield and regression"
legend.x_label = "Yield test"
legend.y_label = "Yield predict"
metric.plot_true_vs_predicted(legend=legend)

# %% [markdown]
# Plot $r^2$

# %%
legend = PlotLegends()
legend.first_plot_label = "{variable}, and yield test"
legend.second_plot_label = "{variable}, and yield predict"
legend.title = "Plot of {variable} ans yield with R2 = {r2:.2f}"
legend.x_label = "{variable}"
legend.y_label = "Yield predict"
features = preprocessing.get_name_features()
#metric.plot_r2_predicted(legend=legend, features=features)

# %% [markdown]
# Get the predict that are more bigger that .05

# %%
metric.list_percentage_error_upper(pivot=.04, sort = 'error')
# Out:
# [{'truth': 226.1118, 'predict': 649.9161723662216, 'error': 1.874313381107141},
#  {'truth': 304.5419,
#   'predict': 649.9161722697179,
#   'error': 1.1340780111692936},
#  {'truth': 322.9881,
#   'predict': 649.9161724834715,
#   'error': 1.0121985066430361},
#  {'truth': 360.0, 'predict': 649.9161724455603, 'error': 0.8053227012376675},
#  {'truth': 398.2896,
#   'predict': 649.9161722273577,
#   'error': 0.6317678699804306},
#  {'truth': 400.8056,
#   'predict': 649.9161721208706,
#   'error': 0.6215246795974669},
#  {'truth': 409.865, 'predict': 649.9161722802547, 'error': 0.5856835111079373},
#  {'truth': 427.0, 'predict': 649.9161722564222, 'error': 0.5220519256590684},
#  {'truth': 436.0, 'predict': 649.916171849747, 'error': 0.49063342167373164},
#  {'truth': 437.0, 'predict': 649.9161723815114, 'error': 0.48722236242908784},
#  {'truth': 438.9351,
#   'predict': 649.9161723713243,
#   'error': 0.48066575758312396},
#  {'truth': 453.0, 'predict': 649.9161724096404, 'error': 0.4346935373281244},
#  {'truth': 455.805,
#   'predict': 649.9161729077582,
#   'error': 0.42586450984030055},
#  {'truth': 459.2263,
#   'predict': 649.9161723912115,
#   'error': 0.4152416191999707},
#  {'truth': 460.0, 'predict': 649.9161730707476, 'error': 0.4128612458059731},
#  {'truth': 468.0, 'predict': 649.9161727676129, 'error': 0.38870977087096775},
#  {'truth': 481.9391,
#   'predict': 649.9161705400991,
#   'error': 0.34854418440026774},
#  {'truth': 491.9464,
#   'predict': 649.9161730116444,
#   'error': 0.32111175732080666},
#  {'truth': 500.4446,
#   'predict': 649.9161726667036,
#   'error': 0.2986775612459473},
#  {'truth': 508.4414,
#   'predict': 649.916172364837,
#   'error': 0.27825187399145124},
#  {'truth': 519.2414, 'predict': 649.9161707989208, 'error': 0.251664776342797},
#  {'truth': 532.0, 'predict': 649.91617476859, 'error': 0.2216469450537407},
#  {'truth': 535.2902,
#   'predict': 649.9161724524295,
#   'error': 0.21413799926176386},
#  {'truth': 538.5554,
#   'predict': 649.9161720612905,
#   'error': 0.20677681824616467},
#  {'truth': 540.0, 'predict': 649.9161722256401, 'error': 0.20354846708451876},
#  {'truth': 543.5405,
#   'predict': 649.9161723561624,
#   'error': 0.19570882456075023},
#  {'truth': 804.0, 'predict': 649.916172281092, 'error': 0.19164655188918903},
#  {'truth': 799.0, 'predict': 649.9161721829839, 'error': 0.1865880197960151},
#  {'truth': 790.0426,
#   'predict': 649.9161729020549,
#   'error': 0.17736565989978909},
#  {'truth': 553.957, 'predict': 649.9161712142757, 'error': 0.1732249456442931},
#  {'truth': 557.3696,
#   'predict': 649.9161717758539,
#   'error': 0.16604165669576143},
#  {'truth': 774.0, 'predict': 649.9161718565049, 'error': 0.16031502344120815},
#  {'truth': 762.0, 'predict': 649.9161701751494, 'error': 0.1470916401900926},
#  {'truth': 568.2109,
#   'predict': 649.916172323581,
#   'error': 0.14379391934153493},
#  {'truth': 572.0, 'predict': 649.9161695930678, 'error': 0.13621707970816052},
#  {'truth': 749.0, 'predict': 649.9161724396602, 'error': 0.13228815428616802},
#  {'truth': 748.0, 'predict': 649.9161723373262, 'error': 0.13112811184849438},
#  {'truth': 575.5569,
#   'predict': 649.9161729429851,
#   'error': 0.12919534618208045},
#  {'truth': 576.6, 'predict': 649.9161724194139, 'error': 0.12715257096672541},
#  {'truth': 579.9627,
#   'predict': 649.9161725275821,
#   'error': 0.12061719232561353},
#  {'truth': 729.0, 'predict': 649.9161722435827, 'error': 0.10848261694981803},
#  {'truth': 587.0, 'predict': 649.9161723642668, 'error': 0.10718257642975605},
#  {'truth': 587.3306,
#   'predict': 649.9161725204464,
#   'error': 0.10655935944840327},
#  {'truth': 724.2887,
#   'predict': 649.9161725422324,
#   'error': 0.10268353966832225},
#  {'truth': 724.0, 'predict': 649.916171940312, 'error': 0.10232572936420997},
#  {'truth': 724.0, 'predict': 649.9161724793147, 'error': 0.10232572861973108},
#  {'truth': 590.1555,
#   'predict': 649.9161724087363,
#   'error': 0.10126258657038079},
#  {'truth': 723.0, 'predict': 649.9161722305, 'error': 0.10108413246127244},
#  {'truth': 723.0, 'predict': 649.9161723915314, 'error': 0.10108413223854577},
#  {'truth': 723.0, 'predict': 649.9161724250658, 'error': 0.10108413219216343},
#  {'truth': 590.605, 'predict': 649.9161723169893, 'error': 0.1004244331100978},
#  {'truth': 591.1686,
#   'predict': 649.9161724073905,
#   'error': 0.09937532610390762},
#  {'truth': 592.0, 'predict': 649.9161726823015, 'error': 0.09783137277415797},
#  {'truth': 592.0, 'predict': 649.9161723019715, 'error': 0.09783137213170866},
#  {'truth': 720.0, 'predict': 649.9161721070632, 'error': 0.09733864985130114},
#  {'truth': 719.887, 'predict': 649.9161719859022, 'error': 0.09719696009804},
#  {'truth': 716.0, 'predict': 649.9161724407917, 'error': 0.09229584854638033},
#  {'truth': 715.0, 'predict': 649.9161698296045, 'error': 0.091026335902651},
#  {'truth': 713.5909,
#   'predict': 649.9161723990712,
#   'error': 0.08923141761046673},
#  {'truth': 713.0, 'predict': 649.916172636586, 'error': 0.08847661621797195},
#  {'truth': 712.0, 'predict': 649.9161718181751, 'error': 0.08719638789582143},
#  {'truth': 598.2015,
#   'predict': 649.9161723944358,
#   'error': 0.08645025529764762},
#  {'truth': 710.0, 'predict': 649.9161725062655, 'error': 0.0846251091461049},
#  {'truth': 709.6073,
#   'predict': 649.9161727368222,
#   'error': 0.08411853607365342},
#  {'truth': 709.0, 'predict': 649.9161727294054, 'error': 0.08333403000083867},
#  {'truth': 600.1704,
#   'predict': 649.9161717213118,
#   'error': 0.08288607988883129},
#  {'truth': 601.0, 'predict': 649.9161722809175, 'error': 0.0813913016321423},
#  {'truth': 707.0, 'predict': 649.9161721587226, 'error': 0.0807409163242962},
#  {'truth': 602.5863,
#   'predict': 649.9161722328045,
#   'error': 0.07854455408761268},
#  {'truth': 704.7524,
#   'predict': 649.9161727952074,
#   'error': 0.07780920959587016},
#  {'truth': 603.0, 'predict': 649.9161727320734, 'error': 0.07780459822897744},
#  {'truth': 703.2617,
#   'predict': 649.9161722541288,
#   'error': 0.07585444756322036},
#  {'truth': 604.1609,
#   'predict': 649.916172777444,
#   'error': 0.07573358815084529},
#  {'truth': 604.6565,
#   'predict': 649.9161725155326,
#   'error': 0.07485187460241069},
#  {'truth': 605.295,
#   'predict': 649.9161723582258,
#   'error': 0.07371805872876179},
#  {'truth': 700.0, 'predict': 649.9161704996324, 'error': 0.07154832785766806},
#  {'truth': 607.1254,
#   'predict': 649.9161723300102,
#   'error': 0.07048094566626634},
#  {'truth': 607.2419,
#   'predict': 649.9161725968696,
#   'error': 0.07027557320545508},
#  {'truth': 695.4481,
#   'predict': 649.9161730026948,
#   'error': 0.06547135148878136},
#  {'truth': 611.0, 'predict': 649.916172217273, 'error': 0.06369258955363832},
#  {'truth': 694.1178,
#   'predict': 649.9161721577694,
#   'error': 0.06368029726687682},
#  {'truth': 612.0, 'predict': 649.9161728269992, 'error': 0.061954530763070545},
#  {'truth': 612.1224,
#   'predict': 649.9161724141519,
#   'error': 0.06174218165215312},
#  {'truth': 691.1499,
#   'predict': 649.9161739173207,
#   'error': 0.05965959928906776},
#  {'truth': 690.806,
#   'predict': 649.916173154552,
#   'error': 0.059191476109715396},
#  {'truth': 615.0, 'predict': 649.9161755669824, 'error': 0.05677426921460547},
#  {'truth': 615.0, 'predict': 649.9161732333831, 'error': 0.05677426542013515},
#  {'truth': 688.527, 'predict': 649.9161724526236, 'error': 0.0560774342144555},
#  {'truth': 616.0, 'predict': 649.916172394165, 'error': 0.05505872141909896},
#  {'truth': 616.1065,
#   'predict': 649.9161720210966,
#   'error': 0.05487634365340508},
#  {'truth': 687.2559,
#   'predict': 649.9161721230469,
#   'error': 0.05433162214679151},
#  {'truth': 616.961,
#   'predict': 649.9161723263934,
#   'error': 0.053415324998489985},
#  {'truth': 617.0, 'predict': 649.9161732843507, 'error': 0.053348741141573335},
#  {'truth': 686.0, 'predict': 649.9161723455816, 'error': 0.05260033185775281},
#  {'truth': 685.0, 'predict': 649.9161722366113, 'error': 0.05121726680786677},
#  {'truth': 618.5932,
#   'predict': 649.9161723177426,
#   'error': 0.0506358173962187},
#  {'truth': 619.8774,
#   'predict': 649.9161722348505,
#   'error': 0.04845921505583284},
#  {'truth': 681.0, 'predict': 649.9161723017274, 'error': 0.04564438722213298},
#  {'truth': 622.0, 'predict': 649.9161721675613, 'error': 0.044881305735629075},
#  {'truth': 680.2429,
#   'predict': 649.916172377481,
#   'error': 0.044582203831188834},
#  {'truth': 680.0, 'predict': 649.9161722988526, 'error': 0.044240923089922585},
#  {'truth': 679.5885,
#   'predict': 649.9161716610595,
#   'error': 0.04366219902034904},
#  {'truth': 623.0015,
#   'predict': 649.916172460349,
#   'error': 0.04320161742844767},
#  {'truth': 679.2389,
#   'predict': 649.9161720992265,
#   'error': 0.043169977309564324},
#  {'truth': 623.6013,
#   'predict': 649.9161723861577,
#   'error': 0.042198232085400744},
#  {'truth': 624.0, 'predict': 649.916172059726, 'error': 0.041532327018791705},
#  {'truth': 624.0551,
#   'predict': 649.9161702030319,
#   'error': 0.0414403635240412},
#  {'truth': 677.9521,
#   'predict': 649.9161715828709,
#   'error': 0.04135384847562103},
#  {'truth': 624.4419,
#   'predict': 649.9161724526134,
#   'error': 0.04079526446353676}]
