# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../../../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from machines.predictions.svr_prediction import SVR_Prediction
from machines.enums import SvrKernelEnum
from preprocesses.preprocess import Preprocess
from preprocesses.enums import TransformEnum, TypeFileEnum, StandardScaleEnum
from metrics.error_metric import ErrorMetric
from metrics.enums import MetricEnum, PlotLegends

# %% [markdown]
# Read the file and prepare data for SVR

# %%
file_csv = '../../../../../../../data/phen/original/phenotypic_weather_obregon_151617_thirty.csv'
print(os.getcwd())
svr = SVR_Prediction(kernel=SvrKernelEnum.POLY)
preprocessing =  Preprocess(file_name=file_csv, type_file=TypeFileEnum.CSV)
preprocessing.read_file(
    transform=TransformEnum.PCA,
    standard_scale=StandardScaleEnum.BASIC,
)
preprocessing.build_train_and_test()
# Out:
# /phen/app/notebooks/phen/pca/phenotypic_weather/svr/thirty

# %% [markdown]
# Launched SVR

# %%
x_train, y_train = preprocessing.get_train()
svr.training(x_train=x_train, y_train=y_train)

# %%
x_test, y_test = preprocessing.get_test()
y_predicted = svr.prediction(x_test=x_test)

# %% [markdown]
# Get metrics

# %%
metric = ErrorMetric(y_predicted=y_predicted, y_test=y_test, x_test=x_test)
metric.calculate_metric_prediction()
print('Root mean squared error -> {}'.format(metric.get_metric(metric=MetricEnum.ROOT_MEAN_SQUARED_ERROR)))
print('R2 -> {}'.format(metric.get_metric(metric=MetricEnum.R2_SCORE)))
print('MAPE -> {}'.format(metric.get_metric(metric=MetricEnum.MEAN_ABSOLUTE_PERCENTAGE_ERROR)))
metric.get_all_from_predict()
# Out:
# Root mean squared error -> 102.47649002856997
# R2 -> -0.09026827911021518
# MAPE -> 0.14324955154293806
# {'d2_absolute_error_score': -0.01936085157489842,
#  'd2_pinball_score': -0.01936085157489842,
#  'd2_tweedie_score': -0.0902682791102154,
#  'explained_variance_score': 0.0017446052646217236,
#  'max_error': 423.0864462878694,
#  'mean_absolute_error': 71.12845801958346,
#  'mean_absolute_percentage_error': 0.14324955154293806,
#  'mean_gamma_deviance': 0.03309352841985185,
#  'mean_poisson_deviance': 18.37780197749788,
#  'mean_squared_error': 10501.4310085756,
#  'mean_squared_log_error': 0.03867675814772135,
#  'median_absolute_error': 45.59856533114743,
#  'r2_score': -0.09026827911021518,
#  'root_mean_squared_error': 102.47649002856997,
#  'root_mean_squared_log_error': 0.19666407436977743}

# %% [markdown]
# Plots:

# %%
legend = PlotLegends()
legend.first_plot_label = "Yield predict"
legend.second_plot_label = "Regression"
legend.title = "Plot of Yield and regression"
legend.x_label = "Yield test"
legend.y_label = "Yield predict"
metric.plot_true_vs_predicted(legend=legend)

# %% [markdown]
# Plot $r^2$

# %%
legend = PlotLegends()
legend.first_plot_label = "{variable}, and yield test"
legend.second_plot_label = "{variable}, and yield predict"
legend.title = "Plot of {variable} ans yield with R2 = {r2:.2f}"
legend.x_label = "{variable}"
legend.y_label = "Yield predict"
features = preprocessing.get_name_features()
#metric.plot_r2_predicted(legend=legend, features=features)

# %% [markdown]
# Get the predict that are more bigger that .05

# %%
metric.list_percentage_error_upper(pivot=.04, sort = 'error')
# Out:
# [{'truth': 226.1118,
#   'predict': 649.1982462878694,
#   'error': 1.8711382877314207},
#  {'truth': 304.5419, 'predict': 649.446880421709, 'error': 1.1325370348766755},
#  {'truth': 322.9881, 'predict': 649.3536390237281, 'error': 1.010456852818194},
#  {'truth': 360.0, 'predict': 649.4978723891651, 'error': 0.8041607566365697},
#  {'truth': 398.2896, 'predict': 649.5002714225743, 'error': 0.63072365289622},
#  {'truth': 400.8056,
#   'predict': 649.6087131144429,
#   'error': 0.6207575770259769},
#  {'truth': 409.865, 'predict': 649.5770218549642, 'error': 0.5848560424895128},
#  {'truth': 427.0, 'predict': 649.605489262329, 'error': 0.5213243308251264},
#  {'truth': 436.0, 'predict': 649.5720509628471, 'error': 0.4898441535845118},
#  {'truth': 437.0, 'predict': 649.6441488652389, 'error': 0.48659988298681667},
#  {'truth': 438.9351,
#   'predict': 649.6434078849492,
#   'error': 0.4800443343103552},
#  {'truth': 453.0, 'predict': 649.3812105453529, 'error': 0.4335126060603817},
#  {'truth': 455.805,
#   'predict': 649.6264426918636,
#   'error': 0.42522886473791127},
#  {'truth': 459.2263,
#   'predict': 649.6178562561704,
#   'error': 0.41459201325396744},
#  {'truth': 460.0, 'predict': 649.5037931481916, 'error': 0.4119647677134599},
#  {'truth': 468.0, 'predict': 649.4388419316944, 'error': 0.3876898331873811},
#  {'truth': 481.9391,
#   'predict': 649.5782831054996,
#   'error': 0.3478430845422163},
#  {'truth': 491.9464,
#   'predict': 649.6664760668518,
#   'error': 0.3206041879091947},
#  {'truth': 500.4446,
#   'predict': 649.4811444113412,
#   'error': 0.2978082777021498},
#  {'truth': 508.4414,
#   'predict': 649.5044783553494,
#   'error': 0.2774421562747436},
#  {'truth': 519.2414,
#   'predict': 649.6201416515507,
#   'error': 0.25109465780569645},
#  {'truth': 532.0, 'predict': 649.7157300506871, 'error': 0.22127016926820875},
#  {'truth': 535.2902,
#   'predict': 649.6410316386288,
#   'error': 0.21362399617745426},
#  {'truth': 538.5554,
#   'predict': 649.5819899054316,
#   'error': 0.20615630240720192},
#  {'truth': 540.0, 'predict': 649.7430669140557, 'error': 0.20322790169269575},
#  {'truth': 543.5405,
#   'predict': 649.5450592739467,
#   'error': 0.19502605468027998},
#  {'truth': 804.0, 'predict': 649.6729453091871, 'error': 0.19194907299852354},
#  {'truth': 799.0, 'predict': 650.2209506825783, 'error': 0.186206569859101},
#  {'truth': 790.0426,
#   'predict': 649.8018337552509,
#   'error': 0.17751038519283532},
#  {'truth': 553.957,
#   'predict': 649.6452009675746,
#   'error': 0.17273579170869693},
#  {'truth': 557.3696,
#   'predict': 649.6493173113467,
#   'error': 0.1655628819931097},
#  {'truth': 774.0, 'predict': 649.8795722354512, 'error': 0.1603623097733189},
#  {'truth': 762.0, 'predict': 649.812782006473, 'error': 0.14722732020147905},
#  {'truth': 568.2109,
#   'predict': 649.6845212700102,
#   'error': 0.14338623435419875},
#  {'truth': 572.0, 'predict': 649.6704997034457, 'error': 0.13578758689413578},
#  {'truth': 749.0, 'predict': 649.6107509828361, 'error': 0.13269592659167415},
#  {'truth': 748.0, 'predict': 650.2790233066497, 'error': 0.13064301696971964},
#  {'truth': 575.5569,
#   'predict': 649.6396761794601,
#   'error': 0.12871494752206097},
#  {'truth': 576.6, 'predict': 649.6297427361927, 'error': 0.12665581466561343},
#  {'truth': 579.9627,
#   'predict': 649.6944300817332,
#   'error': 0.12023485317544247},
#  {'truth': 729.0, 'predict': 649.6580989799091, 'error': 0.10883662691370488},
#  {'truth': 587.0, 'predict': 649.697665772709, 'error': 0.10681033351398467},
#  {'truth': 587.3306,
#   'predict': 649.573705722849,
#   'error': 0.10597626911121097},
#  {'truth': 724.2887,
#   'predict': 649.7281072500984,
#   'error': 0.10294319481983014},
#  {'truth': 724.0, 'predict': 649.7393164639817, 'error': 0.10257000488400317},
#  {'truth': 724.0, 'predict': 649.8020468014688, 'error': 0.10248336077145193},
#  {'truth': 723.0, 'predict': 649.4387769096305, 'error': 0.10174443027713621},
#  {'truth': 723.0, 'predict': 649.7156885710388, 'error': 0.10136142659607364},
#  {'truth': 723.0, 'predict': 649.8689867323665, 'error': 0.1011493959441681},
#  {'truth': 590.1555,
#   'predict': 649.6607903568215,
#   'error': 0.10082984968677162},
#  {'truth': 590.605,
#   'predict': 649.6818872222242,
#   'error': 0.10002774650100181},
#  {'truth': 591.1686,
#   'predict': 649.692308643748,
#   'error': 0.09899664603929915},
#  {'truth': 592.0, 'predict': 650.2039165243604, 'error': 0.09831742656141951},
#  {'truth': 719.887, 'predict': 649.6194547735263, 'error': 0.0976091320255452},
#  {'truth': 720.0, 'predict': 649.7662535011889, 'error': 0.09754687013723766},
#  {'truth': 592.0, 'predict': 649.654321546176, 'error': 0.09738905666583783},
#  {'truth': 716.0, 'predict': 649.8900247315495, 'error': 0.09233236769336664},
#  {'truth': 715.0, 'predict': 649.8221060435553, 'error': 0.09115789364537717},
#  {'truth': 713.5909,
#   'predict': 649.718446914298,
#   'error': 0.08950850282101688},
#  {'truth': 713.0, 'predict': 649.748142347458, 'error': 0.08871228282263949},
#  {'truth': 712.0, 'predict': 650.009137518122, 'error': 0.08706581809252531},
#  {'truth': 598.2015,
#   'predict': 649.6510644113481,
#   'error': 0.08600708024193869},
#  {'truth': 710.0, 'predict': 649.7931048612843, 'error': 0.08479844385734607},
#  {'truth': 709.6073,
#   'predict': 649.7312577789829,
#   'error': 0.08437912380695221},
#  {'truth': 709.0, 'predict': 649.2727829997655, 'error': 0.08424149083248876},
#  {'truth': 600.1704,
#   'predict': 649.5097645373106,
#   'error': 0.0822089268936133},
#  {'truth': 601.0, 'predict': 649.7333021199096, 'error': 0.08108702515791943},
#  {'truth': 707.0, 'predict': 649.8108273577695, 'error': 0.08088991887161309},
#  {'truth': 704.7524,
#   'predict': 649.6626461071588,
#   'error': 0.07816894826160387},
#  {'truth': 602.5863,
#   'predict': 649.6179468155676,
#   'error': 0.07804964503103964},
#  {'truth': 603.0, 'predict': 649.9238516377948, 'error': 0.07781733273266131},
#  {'truth': 703.2617,
#   'predict': 649.6664507282227,
#   'error': 0.07620953803083166},
#  {'truth': 604.1609,
#   'predict': 649.6119705095605,
#   'error': 0.0752300761428959},
#  {'truth': 604.6565,
#   'predict': 649.535004341803,
#   'error': 0.07422148664870534},
#  {'truth': 605.295,
#   'predict': 649.5638300983684,
#   'error': 0.07313595866208779},
#  {'truth': 700.0, 'predict': 649.9533939957181, 'error': 0.07149515143468843},
#  {'truth': 607.1254,
#   'predict': 649.6516757085807,
#   'error': 0.07004529164581266},
#  {'truth': 607.2419,
#   'predict': 649.5588823209276,
#   'error': 0.06968719108633256},
#  {'truth': 695.4481,
#   'predict': 649.7020398472656,
#   'error': 0.06577925822607661},
#  {'truth': 694.1178, 'predict': 649.713378237675, 'error': 0.0639724579348419},
#  {'truth': 611.0, 'predict': 649.5179399032577, 'error': 0.06304081817227117},
#  {'truth': 612.1224,
#   'predict': 649.8504864438971,
#   'error': 0.06163487309710796},
#  {'truth': 612.0, 'predict': 649.6185816692011, 'error': 0.061468270701309065},
#  {'truth': 691.1499,
#   'predict': 649.8782791896147,
#   'error': 0.05971442781136964},
#  {'truth': 690.806,
#   'predict': 649.8533895505603,
#   'error': 0.05928236067642681},
#  {'truth': 615.0, 'predict': 649.8311791831643, 'error': 0.05663606371246227},
#  {'truth': 615.0, 'predict': 649.7207679443704, 'error': 0.056456533242878755},
#  {'truth': 688.527,
#   'predict': 649.7514169821691,
#   'error': 0.056316721084040226},
#  {'truth': 687.2559,
#   'predict': 649.6690153186828,
#   'error': 0.05469125064087075},
#  {'truth': 616.1065,
#   'predict': 649.6065437850326,
#   'error': 0.05437378729981364},
#  {'truth': 616.0, 'predict': 649.4183302094604, 'error': 0.05425053605431875},
#  {'truth': 686.0, 'predict': 649.3804769807327, 'error': 0.05338122889106015},
#  {'truth': 616.961, 'predict': 649.8838522539418, 'error': 0.0533629390738503},
#  {'truth': 617.0, 'predict': 649.6697383835493, 'error': 0.05294933287447215},
#  {'truth': 685.0, 'predict': 650.1341826017401, 'error': 0.05089900350110931},
#  {'truth': 618.5932,
#   'predict': 649.6417304937718,
#   'error': 0.05019216262605497},
#  {'truth': 619.8774,
#   'predict': 649.6904747210215,
#   'error': 0.04809511480983419},
#  {'truth': 681.0, 'predict': 649.9070498768154, 'error': 0.04565778285342812},
#  {'truth': 680.2429,
#   'predict': 649.7349771671384,
#   'error': 0.044848572227452276},
#  {'truth': 622.0, 'predict': 649.6986328291733, 'error': 0.04453156403404073},
#  {'truth': 680.0, 'predict': 649.8204268854313, 'error': 0.0443817251684834},
#  {'truth': 679.5885,
#   'predict': 649.7499593931334,
#   'error': 0.04390677683166587},
#  {'truth': 679.2389,
#   'predict': 649.7923032803003,
#   'error': 0.04335234145114428},
#  {'truth': 623.0015,
#   'predict': 649.6074678675891,
#   'error': 0.04270610563150992},
#  {'truth': 623.6013,
#   'predict': 649.6399578011623,
#   'error': 0.04175529749723458},
#  {'truth': 677.9521,
#   'predict': 649.6781174934295,
#   'error': 0.04170498550940475},
#  {'truth': 624.0551,
#   'predict': 649.7998727734838,
#   'error': 0.041254005893844564},
#  {'truth': 624.0, 'predict': 649.679516294679, 'error': 0.04115307098506257},
#  {'truth': 624.4419,
#   'predict': 649.7109685964072,
#   'error': 0.04046664484943615}]
